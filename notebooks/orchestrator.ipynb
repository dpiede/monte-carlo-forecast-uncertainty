# %% [markdown]
# ## Monte Carlo Simulation with Stationary Bootstrap
# > **For Monthly Point Forecasts**

# %%
from utils import DummyPredictor, create_dummy_ts

# %%
### preparing timeseries data to work with
df = create_dummy_ts()

# %%
df
# Out:
#           Product line Product group     Date  Sales
# 0    Food preservation   Dehydrators  2004-01   78.0
# 1    Food preservation   Dehydrators  2004-02  126.0
# 2    Food preservation   Dehydrators  2004-03  108.0
# 3    Food preservation   Dehydrators  2004-04  163.0
# 4    Food preservation   Dehydrators  2004-05  124.0
# ..                 ...           ...      ...    ...
# 187  Food preservation       Fridges  2004-08  176.0
# 188  Food preservation       Fridges  2004-09  205.0
# 189  Food preservation       Fridges  2004-10   59.0
# 190  Food preservation       Fridges  2004-11  151.0
# 191  Food preservation       Fridges  2004-12  173.0
#
# [192 rows x 4 columns]
